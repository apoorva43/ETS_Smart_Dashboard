# %% [markdown]
# # Uncertainty Visualization Prototypes
#
# - Based on Kay et al. (2016) *When(ish) is My Bus?*
# - Link: <https://idl.cs.washington.edu/files/2016-WhenIsMyBus-CHI.pdf>

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("__file__").resolve().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline
plt.rcParams["figure.dpi"] = 120

# %%
from src.data_loader import load_all_years
from src.uncertainty_plots import (plot_quantile_dotplot,
                                   plot_quantile_dotplot_shared_axis,
                                   plot_quantile_dotplot_diff_axis,
                                   plot_quantile_dotplot_stacked,
                                   plot_trend_with_ci,
                                   plot_replicate_fan)

# %%
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
df = load_all_years(processed_dir=PROCESSED_DIR,
                    years=[2015, 2018, 2022],
                    optimize_memory=True)

print(f"Loaded {len(df):,} rows across years: {sorted(df['YEAR'].unique())}")
# Out:
# Loaded 1,745,082 rows across years: [2015, 2018, 2022]

# %% [markdown]
# ## Quantile Dotplot (May 14 - May 20)

# %%
# Baseline: Two countries, 2022, n_dots=20
fig = plot_quantile_dotplot(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=20,
    oecd_mean=472
)
plt.show()

# %%
# n_dots=40, each=2.5%
fig = plot_quantile_dotplot(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=40,
    oecd_mean=472
)
plt.show()

# %%
# n_dots=80, each=1.25%
fig = plot_quantile_dotplot(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=80,
    oecd_mean=472
)
plt.show()

# %% [markdown]
# ## Quantile Dotplot (May 22 - May 28)

# %% [markdown]
# ### Shared x-axis:

# %%
# n_dots=20
fig = plot_quantile_dotplot_shared_axis(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=20
)
plt.show()

# %%
# n_dots=40
fig = plot_quantile_dotplot_shared_axis(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=40
)
plt.show()

# %% [markdown]
# ### Different x-axis:

# %%
# n_dots=20
fig = plot_quantile_dotplot_diff_axis(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=20
)
plt.show()

# %%
# n_dots=40
fig = plot_quantile_dotplot_diff_axis(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=40
)
plt.show()

# %% [markdown]
# ### Stacked plots:

# %%
# n_dots=20
fig = plot_quantile_dotplot_stacked(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=20
)
plt.show()

# %%
# n_dots=40
fig = plot_quantile_dotplot_stacked(
    df,
    subject="MATH",
    countries=["CAN", "USA"],
    year=2022,
    n_dots=40
)
plt.show()

# %% [markdown]
# ## 95% Confidence Bands

# %%
fig = plot_trend_with_ci(
    df, 
    subject="MATH",                       
    countries=["CAN", "USA"],
    years=None)
plt.show()

# %% [markdown]
# ## 80 Replicate Trend Lines

# %%
fig = plot_replicate_fan(
    df,
    subject="MATH",
    country="CAN",
    years=None)
plt.show()
